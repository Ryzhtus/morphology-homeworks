# %% [markdown]
# # Морфология 2
# В данном ноутбуке находится задание на триграммы и словарь. В качестве текста будем использовать томик войны и мира: https://goo.gl/qcVTLE
#
# Для начала напомним некоторые полезные инструменты на питоне

# %% [markdown]
# ## 1. Инструменты

# %% [markdown]
# ### 1.1. Регулярные выражения
# Исчерпывающий пост https://habr.com/ru/post/349860/

# %%
import re

# С помощью рег. выражения можно искать, заменять и сентезировать строки по шаблонам
# Парочка простых примеров
numbers = re.findall(r'\d+', r'There is some numbers: 49 and 432')
print(u'Находим числа в строке: ', numbers)

print(u'Простенький токенизатор: ', re.sub('[,\.?!]',' ','How, to? split. text!').split())

print(u'Еще один токенизатор: ', re.split(r'\W+', 'How, to? split. text! Again'))

# в качестве тренировки придумайте свой токенизатор в случае, когда из текста нужно получить только русские слова.
# Out:
# Находим числа в строке:  ['49', '432']
# Простенький токенизатор:  ['How', 'to', 'split', 'text']
# Еще один токенизатор:  ['How', 'to', 'split', 'text', 'Again']

# %% [markdown]
# ### 1.2. Чтение файлов
# Чтобы не мучится самим с кодировками, приведем способ чтения файла корпуса.

# %%
import io
import razdel
wordlist = None

with io.open('wp.txt', "r") as text_file:
    text = text_file.read()
    wordlist = razdel.tokenize(text.lower())
    # wordlist = Здесь заиспользуем токенизатор. Также приведем все слова к нижнему регистру.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0130b2189976> in <module>
#       3 wordlist = None
#       4
# ----> 5 with io.open('wp.txt', "r") as text_file:
#       6     text = text_file.read()
#       7     wordlist = razdel.tokenize(text.lower())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wp.txt'

# %% [markdown]
# ### 1.3. ООП
# В питоне можно создавать свои классы, скорее всего нам понадобится класс для хранения бора

# %%
class Trie:
    def __init__(self):
        self.children = {}
        self.is_word = False
    
    def add(self, word):
        if not word:
            print('Аргумент не является словом')
            
        head, *tail = word
        
        if head not in self.children:
            self.children[head] = Trie()
        
        node = self.children[head]
        
        if tail:
            node.add(tail)
        else:
            self.is_word = True

# %%
trie = Trie()
trie.add('he')
trie.add('she')
trie.add('his')
trie.add('hers')
trie.children

# %% [markdown]
# ### 1.4. pyplot
# Довольно часто приходится построить какие-нибудт графики и гистограммы для изучения данных, с которыми придется работать. Для этого в питоне есть удобнейший модуль для этого - pyplot. Туториал: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html

# %%
#!pip install matplotlib # Установка модуля
import matplotlib.pyplot as plt
# команда чтобы картинки рисовались прямо в ноутбуке
# %matplotlib inline

# %%
# Посмотрим на график функции x^2
data = [i * i for i in range(100)]
plt.plot(data)

# %%
# и распределение по значениям
plt.hist(data)

# %% [markdown]
# Также полезная команда для подсчета времения выполнеия в ячейке

# %%
# %%time
res = 0
for i in range(int(1e8)):
    res += 1
# Out:
# Wall time: 10.5 s

# %% [markdown]
# ## 2. Задание
# Собственно теперь нам потребуется написать подсчет триграмм и бор для словаря, чтобы реализовать простенькую систему исправления ошибок.

# %% [markdown]
# ### 2.1. Триграммы
# Для начала получим словарь триграмма - её кол-во в тексте, не забывая о начале и конце слова.
#
# Далее можно построить гистограмму на кол-во вхождений триграмм, и посмотреть самые частые и какая частота у каких-нибудь заведомо странных, например: 'чгк', 'шкя' и подобные. Из полученных данных придумать эвристику, как считать слово с опечаткой. Проверить эвристику по словарю.

# %%
import io
import razdel
wordlist = None

with io.open('war_and_piece.txt', "r") as text_file:
    text = text_file.read()
    wordlist = list(razdel.tokenize(text.lower()))

# %%
def build_corpus_trigrams(words):
    trigrams_and_freq = {}
    
    for word in words:
        marked_word = '##' + word.text + '##'
        
        for char in range(len(marked_word) - 2):
            trigram = marked_word[char: char + 3]
            
            if trigram in trigrams_and_freq:
                trigrams_and_freq[trigram] += 1
            else:
                trigrams_and_freq[trigram] = 1
    
    return trigrams_and_freq

        
def is_error(word, trigrams_and_freq):
    marked_word = '##' + word.text + '##' 
    
    errors = []
    # будем учитывать две триграммы
    for char in range(1, len(marked_word) - 2):
        first_trigram = marked_word[char - 1: char + 2]
        second_trigram = marked_word[char: char + 3]
        votes = 0
        
        if first_trigram in trigrams_and_freq and trigrams_and_freq[first_trigram] > 2:
            votes += 0
        else:
            votes += 1
        
        if second_trigram in trigrams_and_freq and trigrams_and_freq[second_trigram] > 2:
            votes += 0
        else:
            votes += 1
            
        if votes == 2: 
            errors.append(first_trigram)
            errors.append(second_trigram)
            
    if errors:
        return set(errors)
    else:
        return False

# %%
def print_errors(words):
    trigram_dict = build_corpus_trigrams(words)
    for word in words:
        result = is_error(word, trigram_dict)
        if result:
            print('Cлово ->', word.text, '| Возможные ошибки ->', result)

# %%
print_errors(wordlist)
# Out:
# Cлово -> lucques | Возможные ошибки -> {'ucq', 'luc'}
# Cлово -> atrocites | Возможные ошибки -> {'roc', 'oci'}
# Cлово -> генуа | Возможные ошибки -> {'нуа', 'уа#'}
# Cлово -> лукка | Возможные ошибки -> {'кка', 'укк'}
# Cлово -> июле | Возможные ошибки -> {'#ию', 'июл', 'юле'}
# Cлово -> virulente | Возможные ошибки -> {'vir', 'iru'}
# Cлово -> insipides | Возможные ошибки -> {'sip', 'ipi'}
# Cлово -> a-t-on | Возможные ошибки -> {'t-o', '-on'}
# Cлово -> novosiizoff | Возможные ошибки -> {'iiz', 'sii', 'nov', 'izo', 'ovo'}
# Cлово -> a-t-on | Возможные ошибки -> {'t-o', '-on'}
# Cлово -> отжившим | Возможные ошибки -> {'отж', 'тжи'}
# Cлово -> гидру | Возможные ошибки -> {'идр', 'гид'}
# Cлово -> самоотвержения | Возможные ошибки -> {'оот', 'моо'}
# Cлово -> montmorency | Возможные ошибки -> {'ncy', 'cy#', 'ntm', 'tmo'}
# Cлово -> rohans | Возможные ошибки -> {'oha', 'roh'}
# Cлово -> монморанси | Возможные ошибки -> {'нмо', 'онм'}
# Cлово -> abbe | Возможные ошибки -> {'abb', 'bbe'}
# Cлово -> императрица-мать | Возможные ошибки -> {'а-м', 'ца-'}
# Cлово -> funke | Возможные ошибки -> {'unk', 'fun'}
# Cлово -> императрице-матери | Возможные ошибки -> {'е-м', 'це-'}
# Cлово -> безапелляционно | Возможные ошибки -> {'елл', 'лля'}
# Cлово -> lafater | Возможные ошибки -> {'laf', 'afa', 'fat'}
# Cлово -> 40.000 | Возможные ошибки -> {'0.0', '40.', '.00'}
# Cлово -> покой-ер-п | Возможные ошибки -> {'-ер', '-п#', 'р-п', 'й-е'}
# Cлово -> шифре | Возможные ошибки -> {'ифр', 'шиф'}
# Cлово -> seduisante | Возможные ошибки -> {'edu', 'sed'}
# Cлово -> полуоткрытый | Возможные ошибки -> {'луо', 'уот'}
# Cлово -> attifee | Возможные ошибки -> {'fee', 'ife'}
# Cлово -> сыграйте | Возможные ошибки -> {'сыг', 'ыгр'}
# Cлово -> tranquille | Возможные ошибки -> {'anq', 'nqu'}
# Cлово -> красавица-княжна | Возможные ошибки -> {'а-к', '-кн', 'ца-'}
# Cлово -> сверхъестественно-прекрасное | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> сверхъестественно | Возможные ошибки -> {'хъе', 'рхъ'}
# Cлово -> parfait | Возможные ошибки -> {'rfa', 'arf'}
# Cлово -> b | Возможные ошибки -> {'#b#', 'b##'}
# Cлово -> ростбиф | Возможные ошибки -> {'иф#', 'биф'}
# Cлово -> hippolyte | Возможные ошибки -> {'oly', 'ipp', 'lyt', 'yte', 'hip'}
# Cлово -> сестрою-красавицей | Возможные ошибки -> {'ю-к', 'ою-'}
# Cлово -> брюзгливость | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> cuisse | Возможные ошибки -> {'#cu', 'cui'}
# Cлово -> nymphe | Возможные ошибки -> {'phe', 'mph', '#ny', 'ymp', 'nym'}
# Cлово -> нимфы | Возможные ошибки -> {'мфы', 'имф'}
# Cлово -> george | Возможные ошибки -> {'geo', 'eor'}
# Cлово -> мадмуазель | Возможные ошибки -> {'адм', 'дму'}
# Cлово -> жорж | Возможные ошибки -> {'жор', '#жо'}
# Cлово -> koutouzoff | Возможные ошибки -> {'ouz', 'uzo'}
# Cлово -> жорж | Возможные ошибки -> {'жор', '#жо'}
# Cлово -> peuples | Возможные ошибки -> {'eup', 'upl'}
# Cлово -> lucques | Возможные ошибки -> {'ucq', 'luc'}
# Cлово -> лукки | Возможные ошибки -> {'укк', 'кки'}
# Cлово -> изъявляют | Возможные ошибки -> {'зъя', 'изъ'}
# Cлово -> guai | Возможные ошибки -> {'uai', 'gua'}
# Cлово -> elisabeth | Возможные ошибки -> {'eth', 'th#'}
# Cлово -> subissent | Возможные ошибки -> {'ubi', 'bis'}
# Cлово -> bourbons | Возможные ошибки -> {'urb', 'rbo'}
# Cлово -> usurpateur | Возможные ошибки -> {'usu', 'urp', '#us', 'pat', 'rpa'}
# Cлово -> azur | Возможные ошибки -> {'zur', 'azu', '#az'}
# Cлово -> геральдических | Возможные ошибки -> {'дич', 'ьди'}
# Cлово -> gloire | Возможные ошибки -> {'loi', '#gl', 'glo'}
# Cлово -> marietyr | Возможные ошибки -> {'yr#', 'ety', 'tyr'}
# Cлово -> злоупотребления | Возможные ошибки -> {'оуп', 'лоу'}
# Cлово -> social | Возможные ошибки -> {'soc', 'cia', 'oci'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> яффе | Возможные ошибки -> {'яфф', '#яф'}
# Cлово -> anecdote | Возможные ошибки -> {'ane', 'nec', 'dot', 'cdo', 'ecd'}
# Cлово -> moscovite | Возможные ошибки -> {'ovi', 'cov'}
# Cлово -> excusez | Возможные ошибки -> {'xcu', 'cus'}
# Cлово -> pied | Возможные ошибки -> {'ied', 'ed#'}
# Cлово -> незапно | Возможные ошибки -> {'апн', 'пно'}
# Cлово -> неуклюж | Возможные ошибки -> {'люж', 'юж#'}
# Cлово -> па-звольте | Возможные ошибки -> {'па-', '-зв', 'а-з'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'-a-', '-fa', 't-a', 'a-f'}
# Cлово -> innocent | Возможные ошибки -> {'noc', 'oce'}
# Cлово -> regnant | Возможные ошибки -> {'egn', 'gna'}
# Cлово -> гувернером-аббатом | Возможные ошибки -> {'м-а', '-аб'}
# Cлово -> свяжи | Возможные ошибки -> {'яжи', 'вяж'}
# Cлово -> образцом | Возможные ошибки -> {'азц', 'зцо'}
# Cлово -> июньская | Возможные ошибки -> {'#ию', 'июн', 'ньс', 'юнь'}
# Cлово -> бесхарактерными | Возможные ошибки -> {'сха', 'есх'}
# Cлово -> бретёр | Возможные ошибки -> {'етё', 'ёр#', 'тёр'}
# Cлово -> *** | Возможные ошибки -> {'*##', '**#', '##*', '***', '#**'}
# Cлово -> радзивилов | Возможные ошибки -> {'адз', 'дзи'}
# Cлово -> цуги | Возможные ошибки -> {'цуг', '#цу'}
# Cлово -> камчатные | Возможные ошибки -> {'амч', 'мча'}
# Cлово -> подзывал | Возможные ошибки -> {'дзы', 'одз'}
# Cлово -> longtemps | Возможные ошибки -> {'ong', 'gte', 'ngt'}
# Cлово -> razoumowsky | Возможные ошибки -> {'sky', 'azo', 'oum', 'ky#', 'raz', 'umo', 'mow', 'ows', 'wsk'}
# Cлово -> паузе | Возможные ошибки -> {'ауз', 'пау'}
# Cлово -> медведю | Возможные ошибки -> {'дю#', 'едю'}
# Cлово -> lorrain | Возможные ошибки -> {'orr', 'lor'}
# Cлово -> гостьи-барышни | Возможные ошибки -> {'и-б', 'ьи-'}
# Cлово -> соня-племянница | Возможные ошибки -> {'-пл', 'я-п', 'ня-'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ью-', 'ю-б'}
# Cлово -> гостью-барышню | Возможные ошибки -> {'ью-', 'ю-б'}
# Cлово -> секреты-то | Возможные ошибки -> {'ы-т', 'ты-'}
# Cлово -> шепчущая | Возможные ошибки -> {'пчу', 'епч'}
# Cлово -> глубже | Возможные ошибки -> {'бже', 'убж'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'#с-', 'с-г'}
# Cлово -> жанлис | Возможные ошибки -> {'анл', 'нли'}
# Cлово -> lorrain | Возможные ошибки -> {'orr', 'lor'}
# Cлово -> humanum | Возможные ошибки -> {'num', 'anu'}
# Cлово -> stupide | Возможные ошибки -> {'#st', 'tup', 'upi', 'stu'}
# Cлово -> salut | Возможные ошибки -> {'alu', 'lut'}
# Cлово -> княжен-племянниц | Возможные ошибки -> {'н-п', 'ен-', '-пл'}
# Cлово -> combien | Возможные ошибки -> {'omb', 'mbi'}
# Cлово -> зачумленный | Возможные ошибки -> {'чум', 'умл'}
# Cлово -> jacquot | Возможные ошибки -> {'acq', 'jac'}
# Cлово -> jacquot | Возможные ошибки -> {'acq', 'jac'}
# Cлово -> ахросимову | Возможные ошибки -> {'хро', 'ахр'}
# Cлово -> dragon | Возможные ошибки -> {'ago', 'gon'}
# Cлово -> honorable | Возможные ошибки -> {'nor', 'ono'}
# Cлово -> альфонс | Возможные ошибки -> {'льф', 'ьфо'}
# Cлово -> карлыч | Возможные ошибки -> {'лыч', 'рлы'}
# Cлово -> нет-с | Возможные ошибки -> {'ет-', 'т-с'}
# Cлово -> двухсот | Возможные ошибки -> {'ухс', 'хсо'}
# Cлово -> двухсот | Возможные ошибки -> {'ухс', 'хсо'}
# Cлово -> roverbe | Возможные ошибки -> {'erb', 'rbe'}
# Cлово -> хозяева | Возможные ошибки -> {'зяе', 'яев'}
# Cлово -> razoumovsky | Возможные ошибки -> {'mov', 'sky', 'azo', 'oum', 'raz', 'umo', 'vsk', 'ky#', 'ovs'}
# Cлово -> яхонтовые | Возможные ошибки -> {'#ях', 'яхо'}
# Cлово -> резче | Возможные ошибки -> {'зче', 'езч'}
# Cлово -> rabattu | Возможные ошибки -> {'ttu', 'tu#'}
# Cлово -> ъ | Возможные ошибки -> {'#ъ#', 'ъ##', '##ъ'}
# Cлово -> ь | Возможные ошибки -> {'##ь', '#ь#'}
# Cлово -> затэм | Возможные ошибки -> {'атэ', 'эм#', 'тэм'}
# Cлово -> импэ | Возможные ошибки -> {'мпэ', 'пэ#'}
# Cлово -> знаэ | Возможные ошибки -> {'наэ', 'аэ#'}
# Cлово -> манифэ | Возможные ошибки -> {'фэ#', 'ифэ'}
# Cлово -> нэ | Возможные ошибки -> {'нэ#', '#нэ'}
# Cлово -> можэ | Возможные ошибки -> {'ожэ', 'жэ#'}
# Cлово -> смотрэт | Возможные ошибки -> {'рэт', 'трэ', 'эт#'}
# Cлово -> бэ | Возможные ошибки -> {'#бэ', 'бэ#'}
# Cлово -> зачэм | Возможные ошибки -> {'ачэ', 'чэм', 'эм#'}
# Cлово -> поощрением | Возможные ошибки -> {'ощр', 'оощ', 'щре'}
# Cлово -> proverbe | Возможные ошибки -> {'erb', 'rbe'}
# Cлово -> послэ | Возможные ошибки -> {'слэ', 'лэ#'}
# Cлово -> днэ | Возможные ошибки -> {'нэ#', 'днэ'}
# Cлово -> умэ | Возможные ошибки -> {'мэ#', 'умэ'}
# Cлово -> р-р-рэ | Возможные ошибки -> {'-рэ', 'рэ#'}
# Cлово -> своэ | Возможные ошибки -> {'воэ', 'оэ#'}
# Cлово -> импэ | Возможные ошибки -> {'мпэ', 'пэ#'}
# Cлово -> всэ | Возможные ошибки -> {'сэ#', 'всэ'}
# Cлово -> й | Возможные ошибки -> {'#й#', '##й'}
# Cлово -> будэ | Возможные ошибки -> {'удэ', 'дэ#'}
# Cлово -> напыщенно | Возможные ошибки -> {'пыщ', 'ыще'}
# Cлово -> настоящэ | Возможные ошибки -> {'ящэ', 'щэ#'}
# Cлово -> й | Возможные ошибки -> {'#й#', '##й'}
# Cлово -> человэк | Возможные ошибки -> {'овэ', 'вэк'}
# Cлово -> сыграла | Возможные ошибки -> {'сыг', 'ыгр'}
# Cлово -> у-у-у | Возможные ошибки -> {'#у-', '-у#', '-у-', 'у-у'}
# Cлово -> горьче | Возможные ошибки -> {'рьч', 'ьче'}
# Cлово -> вот-вот | Возможные ошибки -> {'от-', 'т-в'}
# Cлово -> вежливостью | Возможные ошибки -> {'жли', 'ежл'}
# Cлово -> молодецки-хитрою | Возможные ошибки -> {'и-х', '-хи'}
# Cлово -> граф-то | Возможные ошибки -> {'ф-т', 'аф-'}
# Cлово -> est-ce-pas | Возможные ошибки -> {'-pa', 'e-p'}
# Cлово -> шифоньерок | Возможные ошибки -> {'ифо', 'шиф'}
# Cлово -> шкапчиков | Возможные ошибки -> {'апч', 'пчи'}
# Cлово -> ширм | Возможные ошибки -> {'ирм', 'рм#'}
# Cлово -> нагло-шутливо | Возможные ошибки -> {'-шу', 'о-ш'}
# Cлово -> всём | Возможные ошибки -> {'сём', 'ём#'}
# Cлово -> clair | Возможные ошибки -> {'cla', '#cl'}
# Cлово -> онуфриичем | Возможные ошибки -> {'уфр', 'нуф'}
# Cлово -> sophie | Возможные ошибки -> {'oph', 'sop'}
# Cлово -> подзывая | Возможные ошибки -> {'дзы', 'одз'}
# Cлово -> agonie | Возможные ошибки -> {'ago', 'gon'}
# Cлово -> полуосвещенную | Возможные ошибки -> {'луо', 'уос'}
# Cлово -> docteur | Возможные ошибки -> {'doc', 'oct'}
# Cлово -> a-t-il | Возможные ошибки -> {'t-i', '-il'}
# Cлово -> demi-heure | Возможные ошибки -> {'-he', 'i-h', 'mi-'}
# Cлово -> церкви | Возможные ошибки -> {'ркв', 'кви'}
# Cлово -> церкви | Возможные ошибки -> {'ркв', 'кви'}
# Cлово -> француз-доктор | Возможные ошибки -> {'уз-', 'з-д'}
# Cлово -> резче | Возможные ошибки -> {'зче', 'езч'}
# Cлово -> необычайно-широким | Возможные ошибки -> {'о-ш', '-ши'}
# Cлово -> неуклюжее | Возможные ошибки -> {'люж', 'юже'}
# Cлово -> щипанье | Возможные ошибки -> {'щип', '#щи'}
# Cлово -> assoupi | Возможные ошибки -> {'pi#', 'upi'}
# Cлово -> туалетах | Возможные ошибки -> {'туа', 'уал'}
# Cлово -> жемчугах | Возможные ошибки -> {'емч', 'чуг', 'мчу'}
# Cлово -> толще | Возможные ошибки -> {'лще', 'олщ'}
# Cлово -> conjure | Возможные ошибки -> {'nju', 'jur'}
# Cлово -> soutndra | Возможные ошибки -> {'tnd', 'utn'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> мадмуазель | Возможные ошибки -> {'адм', 'дму'}
# Cлово -> алгебры | Возможные ошибки -> {'алг', 'лге', 'геб'}
# Cлово -> ногтем | Возможные ошибки -> {'огт', 'гте'}
# Cлово -> элоизы | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> старчески-едким | Возможные ошибки -> {'и-е', '-ед'}
# Cлово -> abc | Возможные ошибки -> {'bc#', 'abc'}
# Cлово -> стерпится-слюбится | Возможные ошибки -> {'я-с', 'ся-'}
# Cлово -> элоиза | Возможные ошибки -> {'лои', 'эло'}
# Cлово -> effrayante | Возможные ошибки -> {'yan', 'aya'}
# Cлово -> indissolubles | Возможные ошибки -> {'olu', 'lub'}
# Cлово -> revolte | Возможные ошибки -> {'vol', 'olt'}
# Cлово -> puis-je | Возможные ошибки -> {'s-j', 'is-', '-je'}
# Cлово -> 211 | Возможные ошибки -> {'#21', '211', '11#'}
# Cлово -> lui-meme | Возможные ошибки -> {'i-m', 'ui-'}
# Cлово -> corsicain | Возможные ошибки -> {'rsi', 'ors'}
# Cлово -> tout-р | Возможные ошибки -> {'t-р', '-р#'}
# Cлово -> enthousiasme | Возможные ошибки -> {'tho', 'hou'}
# Cлово -> noblesse | Возможные ошибки -> {'nob', 'obl'}
# Cлово -> vingt | Возможные ошибки -> {'gt#', 'ngt'}
# Cлово -> par-dessus | Возможные ошибки -> {'sus', 'ar-', 'ssu', 'r-d'}
# Cлово -> legitime | Возможные ошибки -> {'leg', 'git', 'egi'}
# Cлово -> consequent | Возможные ошибки -> {'equ', 'seq'}
# Cлово -> legs | Возможные ошибки -> {'leg', 'gs#', 'egs'}
# Cлово -> amuse | Возможные ошибки -> {'mus', 'amu'}
# Cлово -> observer | Возможные ошибки -> {'obs', '#ob'}
# Cлово -> paru | Возможные ошибки -> {'ru#', 'aru'}
# Cлово -> amuse | Возможные ошибки -> {'mus', 'amu'}
# Cлово -> nullement | Возможные ошибки -> {'nul', 'ull'}
# Cлово -> projet | Возможные ошибки -> {'oje', 'roj'}
# Cлово -> anatole | Возможные ошибки -> {'tol', 'ato'}
# Cлово -> tombe | Возможные ошибки -> {'omb', 'tom'}
# Cлово -> choix | Возможные ошибки -> {'oix', 'hoi'}
# Cлово -> cru | Возможные ошибки -> {'cru', 'ru#'}
# Cлово -> sujet | Возможные ошибки -> {'suj', 'uje'}
# Cлово -> bavardage | Возможные ошибки -> {'dag', 'rda'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> admirable | Возможные ошибки -> {'adm', 'mir', 'dmi'}
# Cлово -> m-elle | Возможные ошибки -> {'m-e', '-el'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> поэзии | Возможные ошибки -> {'оэз', 'эзи'}
# Cлово -> свежо | Возможные ошибки -> {'ежо', 'жо#'}
# Cлово -> дочери-невесты | Возможные ошибки -> {'ри-', 'и-н'}
# Cлово -> 13 | Возможные ошибки -> {'#13', '3##', '13#'}
# Cлово -> julie | Возможные ошибки -> {'uli', 'jul'}
# Cлово -> devrai-je | Возможные ошибки -> {'ai-', 'i-j', '-je'}
# Cлово -> osais | Возможные ошибки -> {'#os', 'osa'}
# Cлово -> avions | Возможные ошибки -> {'vio', 'avi'}
# Cлово -> ayant | Возможные ошибки -> {'yan', 'aya', '#ay'}
# Cлово -> inspire | Возможные ошибки -> {'spi', 'pir', 'nsp'}
# Cлово -> opinion | Возможные ошибки -> {'#op', 'opi'}
# Cлово -> royaume | Возможные ошибки -> {'aum', 'yau'}
# Cлово -> aura-t-il | Возможные ошибки -> {'t-i', '-il'}
# Cлово -> subir | Возможные ошибки -> {'ubi', 'bir'}
# Cлово -> conception | Возможные ошибки -> {'pti', 'ept'}
# Cлово -> inutile | Возможные ошибки -> {'nut', 'inu'}
# Cлово -> tout-a-fait | Возможные ошибки -> {'-a-', '-fa', 't-a', 'a-f'}
# Cлово -> chretnne | Возможные ошибки -> {'tnn', 'etn'}
# Cлово -> evangile | Возможные ошибки -> {'ngi', 'gil'}
# Cлово -> ceux-la | Возможные ошибки -> {'x-l', '-la', 'ux-'}
# Cлово -> mysterux | Возможные ошибки -> {'eru', 'rux'}
# Cлово -> etudr | Возможные ошибки -> {'tud', 'etu'}
# Cлово -> principes | Возможные ошибки -> {'ipe', 'pes'}
# Cлово -> ici-bas | Возможные ошибки -> {'ci-', '-ba', 'i-b'}
# Cлово -> persuadons-nous | Возможные ошибки -> {'sua', 'uad', 'rsu'}
# Cлово -> agreable | Возможные ошибки -> {'rea', 'eab'}
# Cлово -> rejette | Возможные ошибки -> {'eje', 'rej'}
# Cлово -> approfondir | Возможные ошибки -> {'rof', 'ofo'}
# Cлово -> plutot | Возможные ошибки -> {'uto', 'tot', 'lut'}
# Cлово -> projet | Возможные ошибки -> {'oje', 'roj'}
# Cлово -> tout-puissant | Возможные ошибки -> {'-pu', 't-p'}
# Cлово -> inquieter | Возможные ошибки -> {'inq', 'nqu'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> avant-hier | Возможные ошибки -> {'t-h', '-hi'}
# Cлово -> lequel | Возможные ошибки -> {'leq', 'equ'}
# Cлово -> sanglots | Возможные ошибки -> {'glo', 'lot'}
# Cлово -> 13-го | Возможные ошибки -> {'#13', '13-', '3-г'}
# Cлово -> juger | Возможные ошибки -> {'uge', 'jug'}
# Cлово -> дюссековой | Возможные ошибки -> {'дюс', 'юсс'}
# Cлово -> exerce | Возможные ошибки -> {'exe', 'xer'}
# Cлово -> doucement | Возможные ошибки -> {'cem', 'uce'}
# Cлово -> surprendre | Возможные ошибки -> {'rpr', 'urp'}
# Cлово -> belle-soeur | Возможные ошибки -> {'le-', '-so', 'soe', 'e-s'}
# Cлово -> мамзель | Возможные ошибки -> {'амз', 'мзе'}
# Cлово -> одынцова | Возможные ошибки -> {'ынц', 'дын'}
# Cлово -> oia | Возможные ошибки -> {'oia', 'ia#', '#oi'}
# Cлово -> брюзгливым | Возможные ошибки -> {'юзг', 'рюз'}
# Cлово -> сафьяном | Возможные ошибки -> {'саф', 'фья', 'афь'}
# Cлово -> эдак | Возможные ошибки -> {'#эд', 'дак', 'эда'}
# Cлово -> южная | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> malbroug | Возможные ошибки -> {'bro', 'oug', 'ug#', 'lbr', 'alb'}
# Cлово -> рюрика | Возможные ошибки -> {'юри', 'рюр'}
# Cлово -> хофс-кригс-вурст-шнапс-рат | Возможные ошибки -> {'вур', 'т-ш', 'гс-', 'ст-', '-шн', 'апс', 'пс-', 'с-р', '-ву', 'с-в'}
# Cлово -> хофс-кригс-вурст-раты | Возможные ошибки -> {'вур', 'гс-', 'ст-', '-ву', 'т-р', 'с-в'}
# Cлово -> новый-йорк | Возможные ошибки -> {'-йо', 'й-й', 'ый-'}
# Cлово -> admirateur | Возможные ошибки -> {'adm', 'mir', 'dmi'}
# Cлово -> goujat | Возможные ошибки -> {'uja', 'jat'}
# Cлово -> холопского | Возможные ошибки -> {'опс', 'пск'}
# Cлово -> покоях | Возможные ошибки -> {'коя', 'оях'}
# Cлово -> привыкшей | Возможные ошибки -> {'ыкш', 'кше'}
# Cлово -> слёз | Возможные ошибки -> {'лёз', 'ёз#', 'слё'}
# Cлово -> zouboff | Возможные ошибки -> {'ubo', 'bof'}
# Cлово -> с-глазу-на-глаз | Возможные ошибки -> {'#с-', 'с-г'}
# Cлово -> ломбардный | Возможные ошибки -> {'мба', 'омб'}
# Cлово -> bt | Возможные ошибки -> {'#bt', 'bt#'}
# Cлово -> 11-го | Возможные ошибки -> {'#11', '1-г', '11-'}
# Cлово -> как-будто | Возможные ошибки -> {'к-б', '-бу'}
# Cлово -> бесшоссейной | Возможные ошибки -> {'сшо', 'шос'}
# Cлово -> цугом | Возможные ошибки -> {'цуг', '#цу'}
# Cлово -> кроатов | Возможные ошибки -> {'роа', 'оат'}
# Cлово -> рявкнул | Возможные ошибки -> {'вкн', 'явк'}
# Cлово -> 217 | Возможные ошибки -> {'#21', '17#', '217'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'в-т', 'чь-', '-в-', 'ь-в'}
# Cлово -> субалтерн-офицеру | Возможные ошибки -> {'рн-', 'н-о'}
# Cлово -> субалтерн-офицер | Возможные ошибки -> {'рн-', 'н-о'}
# Cлово -> федешоу | Возможные ошибки -> {'шоу', 'оу#'}
# Cлово -> турции | Возможные ошибки -> {'урц', 'рци'}
# Cлово -> солдат-песенников | Возможные ошибки -> {'ат-', 'т-п'}
# Cлово -> пляшущего | Возможные ошибки -> {'яшу', 'шущ', 'ляш'}
# Cлово -> буйному | Возможные ошибки -> {'буй', 'уйн'}
# Cлово -> фараон | Возможные ошибки -> {'аон', 'рао'}
# Cлово -> дай-ка | Возможные ошибки -> {'ай-', 'й-к'}
# Cлово -> vollkommen | Возможные ошибки -> {'lko', 'kom', 'llk'}
# Cлово -> zusammengehaltene | Возможные ошибки -> {'amm', 'eha', 'sam', 'usa', 'zus', 'geh'}
# Cлово -> krafte | Возможные ошибки -> {'raf', '#kr', 'kra'}
# Cлово -> nahe | Возможные ошибки -> {'ahe', 'nah'}
# Cлово -> angreifen | Возможные ошибки -> {'eif', 'ife'}
# Cлово -> beiden | Возможные ошибки -> {'eid', 'bei'}
# Cлово -> uferien | Возможные ошибки -> {'ufe', '#uf'}
# Cлово -> bleiben | Возможные ошибки -> {'eib', 'ibe'}
# Cлово -> augenblick | Возможные ошибки -> {'uge', 'nbl', 'aug', 'enb'}
# Cлово -> ubersetzen | Возможные ошибки -> {'ube', 'zen', '#ub', 'etz', 'set', 'rse', 'tze'}
# Cлово -> communikations-linie | Возможные ошибки -> {'ika', 'kat', '-li', 's-l', 'mun', 'mmu', 'nik'}
# Cлово -> unterhalb | Возможные ошибки -> {'rha', 'erh', 'lb#', 'alb', 'b##'}
# Cлово -> solche | Возможные ошибки -> {'olc', 'lch'}
# Cлово -> zeitpunkt | Возможные ошибки -> {'nkt', 'itp', 'pun', 'zei', 'kt#', '#ze', 'unk', 'tpu'}
# Cлово -> kaiserlich-ruseische | Возможные ошибки -> {'kai', 'h-r', '#ka', '-ru', 'ch-'}
# Cлово -> ausgerustet | Возможные ошибки -> {'sge', 'usg'}
# Cлово -> muthig | Возможные ошибки -> {'mut', 'uth'}
# Cлово -> entgegenharren | Возможные ошибки -> {'nha', 'ntg', 'tge', 'enh'}
# Cлово -> sodann | Возможные ошибки -> {'oda', 'sod'}
# Cлово -> gemeinschaftlich | Возможные ошибки -> {'tli', 'ftl'}
# Cлово -> moglichkeit | Возможные ошибки -> {'ogl', 'mog', 'kei', 'gli', 'chk', 'hke'}
# Cлово -> schicksal | Возможные ошибки -> {'ksa', 'ick', 'hic', 'cks'}
# Cлово -> zuzubereiten | Возможные ошибки -> {'zuz', 'uzu', 'zub', 'ube'}
# Cлово -> коммуникационную | Возможные ошибки -> {'мму', 'омм'}
# Cлово -> товарищами-сослуживцами | Возможные ошибки -> {'и-с', 'ми-'}
# Cлово -> зашибся | Возможные ошибки -> {'бся', 'ибс'}
# Cлово -> gott | Возможные ошибки -> {'ott', 'got', 'tt#'}
# Cлово -> garcon | Возможные ошибки -> {'arc', 'rco'}
# Cлово -> 11 | Возможные ошибки -> {'#11', '11#'}
# Cлово -> хозяин-немец | Возможные ошибки -> {'н-н', 'ин-'}
# Cлово -> фуфайке | Возможные ошибки -> {'фуф', 'уфа', 'фай'}
# Cлово -> oestreicher | Возможные ошибки -> {'#oe', 'oes'}
# Cлово -> kaiser | Возможные ошибки -> {'kai', '#ka'}
# Cлово -> немцем-хозяином | Возможные ошибки -> {'м-х', '-хо'}
# Cлово -> welt | Возможные ошибки -> {'elt', 'lt#'}
# Cлово -> vivat | Возможные ошибки -> {'iva', 'vat'}
# Cлово -> welt | Возможные ошибки -> {'elt', 'lt#'}
# Cлово -> чикчиры | Возможные ошибки -> {'кчи', 'икч', 'чир'}
# Cлово -> кг | Возможные ошибки -> {'#кг', 'кг#'}
# Cлово -> кг | Возможные ошибки -> {'#кг', 'кг#'}
# Cлово -> правду-матку | Возможные ошибки -> {'ду-', 'у-м'}
# Cлово -> 23-го | Возможные ошибки -> {'#23', '23-', '3-г'}
# Cлово -> доппелькюмелем | Возможные ошибки -> {'ькю', 'кюм'}
# Cлово -> тащут | Возможные ошибки -> {'щут', 'ащу'}
# Cлово -> нут-ка | Возможные ошибки -> {'ут-', 'т-к'}
# Cлово -> полуулыбаясь | Возможные ошибки -> {'уул', 'луу'}
# Cлово -> подбадривает | Возможные ошибки -> {'дба', 'бад'}
# Cлово -> мундштука | Возможные ошибки -> {'дшт', 'ндш'}
# Cлово -> точь-в-точь | Возможные ошибки -> {'в-т', 'чь-', '-в-', 'ь-в'}
# Cлово -> кое-где | Возможные ошибки -> {'-гд', 'е-г'}
# Cлово -> hexo | Возможные ошибки -> {'hex', 'exo', 'xo#'}
# Cлово -> ламбахе | Возможные ошибки -> {'мба', 'амб'}
# Cлово -> амштетене | Возможные ошибки -> {'мшт', 'амш'}
# Cлово -> 28-го | Возможные ошибки -> {'8-г', '28-'}
# Cлово -> 30-го | Возможные ошибки -> {'30-', '#30'}
# Cлово -> ямщику | Возможные ошибки -> {'ямщ', 'мщи', '#ям'}
# Cлово -> hochgeboren | Возможные ошибки -> {'chg', 'hge', 'geb'}
# Cлово -> генерала-фельдмаршала | Возможные ошибки -> {'а-ф', '-фе', 'ла-'}
# Cлово -> циркуляр | Возможные ошибки -> {'ирк', '#ци', 'цир'}
# Cлово -> bilibine | Возможные ошибки -> {'ibi', 'lib'}
# Cлово -> colportaient | Возможные ошибки -> {'lpo', 'olp'}
# Cлово -> professe | Возможные ошибки -> {'ofe', 'rof', 'fes'}
# Cлово -> victoire | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> victorieuses | Возможные ошибки -> {'cto', 'ict'}
# Cлово -> liebchen | Возможные ошибки -> {'ebc', 'bch', 'ieb'}
# Cлово -> врбна | Возможные ошибки -> {'рбн', 'врб'}
# Cлово -> лихтенфельс | Возможные ошибки -> {'нфе', 'енф'}
# Cлово -> echauffouree | Возможные ошибки -> {'fou', 'ffo'}
# Cлово -> дон-жуан | Возможные ошибки -> {'уан', 'н-ж', '-жу', 'жуа'}
# Cлово -> дон-жуан | Возможные ошибки -> {'уан', 'н-ж', '-жу', 'жуа'}
# Cлово -> majeste | Возможные ошибки -> {'aje', 'maj', 'jes'}
# Cлово -> deroge | Возможные ошибки -> {'rog', 'oge'}
# Cлово -> non-intervention | Возможные ошибки -> {'on-', '-in', 'n-i'}
# Cлово -> imputer | Возможные ошибки -> {'mpu', 'put'}
# Cлово -> non-recevoir | Возможные ошибки -> {'on-', 'cev', '-re', 'ece', 'n-r'}
# Cлово -> tu | Возможные ошибки -> {'tu#', '#tu'}
# Cлово -> brunn | Возможные ошибки -> {'unn', 'run'}
# Cлово -> лш | Возможные ошибки -> {'лш#', '#лш'}
# Cлово -> ь | Возможные ошибки -> {'##ь', '#ь#'}
# Cлово -> маршрутов | Возможные ошибки -> {'шру', 'ршр'}
# Cлово -> з-й | Возможные ошибки -> {'з-й', '#з-'}
# Cлово -> erlaucht | Возможные ошибки -> {'lau', 'rla'}
# Cлово -> ziehen | Возможные ошибки -> {'#zi', 'ieh', 'ehe', 'zie'}
# Cлово -> bosewicht | Возможные ошибки -> {'ewi', 'sew', 'wic'}
# Cлово -> wieder | Возможные ошибки -> {'wie', 'ied'}
# Cлово -> ауэсперг | Возможные ошибки -> {'эсп', 'уэс'}
# Cлово -> нынче-завтра | Возможные ошибки -> {'е-з', 'че-'}
# Cлово -> генерал-лейтенант | Возможные ошибки -> {'-ле', 'л-л'}
# Cлово -> ногти | Возможные ошибки -> {'гти', 'огт'}
# Cлово -> heroisme | Возможные ошибки -> {'sme', 'ism'}
# Cлово -> philosophiee | Возможные ошибки -> {'los', 'oph', 'oso', 'ilo', 'sop', 'hil'}
# Cлово -> дилемма | Возможные ошибки -> {'емм', 'мма'}
# Cлово -> эцельсдорфа | Возможные ошибки -> {'орф', 'рфа', 'эце', 'ьсд', '#эц', 'сдо'}
# Cлово -> transportee | Возможные ошибки -> {'nsp', 'spo'}
# Cлово -> 7-го | Возможные ошибки -> {'7-г', '#7-'}
# Cлово -> шлюхой | Возможные ошибки -> {'люх', 'юхо'}
# Cлово -> про-пус-тить | Возможные ошибки -> {'ус-', 'с-т'}
# Cлово -> вьюки | Возможные ошибки -> {'юки', 'ьюк'}
# Cлово -> шрама | Возможные ошибки -> {'шра', '#шр'}
# Cлово -> буксгевденом | Возможные ошибки -> {'укс', 'ксг', 'гев', 'сге'}
# Cлово -> четырехтысячный | Возможные ошибки -> {'хты', 'ехт'}
# Cлово -> schoenbrunn | Возможные ошибки -> {'hoe', 'run', 'unn', 'nbr', 'oen', 'enb'}
# Cлово -> avant-garde | Возможные ошибки -> {'-ga', 't-g'}
# Cлово -> sur-le-champ | Возможные ошибки -> {'ur-', 'le-', '-le', 'r-l'}
# Cлово -> bagage | Возможные ошибки -> {'bag', 'gag', 'aga'}
# Cлово -> celui-ci | Возможные ошибки -> {'i-c', 'ui-', '-ci'}
# Cлово -> napoleon | Возможные ошибки -> {'eon', 'leo'}
# Cлово -> 4.000-ный | Возможные ошибки -> {'4.0', '0-н', '#4.', '.00', '-ны', '00-'}
# Cлово -> алмазным | Возможные ошибки -> {'алм', 'лма'}
# Cлово -> каптенармус | Возможные ошибки -> {'апт', 'пте'}
# Cлово -> глянь-ка | Возможные ошибки -> {'ь-к', 'нь-'}
# Cлово -> хранцуз-то | Возможные ошибки -> {'уз-', 'з-т'}
# Cлово -> по-хранцузски | Возможные ошибки -> {'-хр', 'о-х'}
# Cлово -> часовой-артиллерист | Возможные ошибки -> {'-ар', 'й-а'}
# Cлово -> эшелонами | Возможные ошибки -> {'эше', '#эш'}
# Cлово -> лемарруа | Возможные ошибки -> {'руа', 'рру', 'уа#'}
# Cлово -> камлотовой | Возможные ошибки -> {'амл', 'мло'}
# Cлово -> пыхтя | Возможные ошибки -> {'ыхт', 'хтя'}
# Cлово -> vaillamment | Возможные ошибки -> {'amm', 'lam'}
# Cлово -> resolument | Возможные ошибки -> {'olu', 'lum'}
# Cлово -> ceda | Возможные ошибки -> {'eda', 'ced'}
# Cлово -> штиблетах | Возможные ошибки -> {'шти', 'тиб'}
# Cлово -> оставляяй | Возможные ошибки -> {'яй#', 'яяй'}
# Cлово -> ысыо | Возможные ошибки -> {'ыо#', 'сыо'}
# Cлово -> !! | Возможные ошибки -> {'!!#', '#!!'}
# Cлово -> двухпудовая | Возможные ошибки -> {'ухп', 'хпу'}
# Cлово -> разъяренное | Возможные ошибки -> {'зъя', 'яре', 'ъяр'}
# Cлово -> подгоняя | Возможные ошибки -> {'одг', 'дго'}
# Cлово -> уцелевшие | Возможные ошибки -> {'уце', '#уц'}
# Cлово -> солдат-артиллерист | Возможные ошибки -> {'ат-', '-ар', 'т-а'}
# Cлово -> гунтерсдорф | Возможные ошибки -> {'рсд', 'сдо'}
# Cлово -> этот-то | Возможные ошибки -> {'от-', 'т-т'}
# Cлово -> статуеобразная | Возможные ошибки -> {'уео', 'туе'}
# Cлово -> 30 | Возможные ошибки -> {'30#', '#30'}
# Cлово -> давным-давно | Возможные ошибки -> {'-да', 'м-д'}
# Cлово -> 1806 | Возможные ошибки -> {'06#', '806'}
# Cлово -> vues | Возможные ошибки -> {'vue', '#vu'}
# Cлово -> minutes | Возможные ошибки -> {'min', 'nut', 'inu'}
# Cлово -> слюни | Возможные ошибки -> {'юни', 'люн'}
# Cлово -> скрып | Возможные ошибки -> {'ып#', 'рып'}
# Cлово -> заодно | Возможные ошибки -> {'зао', 'аод'}
# Cлово -> лёлины | Возможные ошибки -> {'ёли', 'лёл', '#лё'}
# Cлово -> ощутительнее | Возможные ошибки -> {'ощу', 'щут', '#ощ'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> рескрипт | Возможные ошибки -> {'ипт', 'пт#'}
# Cлово -> — | Возможные ошибки -> {'—##', '#—#', '##—'}
# Cлово -> вызывающе-счастливой | Возможные ошибки -> {'ще-', '-сч', 'е-с'}
# Cлово -> 50 | Возможные ошибки -> {'#50', '##5', '50#'}
# Cлово -> brillant | Возможные ошибки -> {'ril', 'bri'}
# Cлово -> красавицы-жены | Возможные ошибки -> {'ы-ж', 'цы-'}
# Cлово -> крюк | Возможные ошибки -> {'рюк', 'юк#', 'крю'}
# Cлово -> рыхлую | Возможные ошибки -> {'хлу', 'ыхл'}
# Cлово -> прешпекту | Возможные ошибки -> {'ешп', 'шпе'}
# Cлово -> кх | Возможные ошибки -> {'#кх', 'кх#'}
# Cлово -> кх | Возможные ошибки -> {'#кх', 'кх#'}
# Cлово -> буфетчику | Возможные ошибки -> {'буф', 'уфе'}
# Cлово -> обжившись | Возможные ошибки -> {'обж', 'бжи'}
# Cлово -> kouraguine | Возможные ошибки -> {'gui', 'uin', 'agu'}
# Cлово -> прешпекте | Возможные ошибки -> {'ешп', 'шпе'}
# Cлово -> камзол | Возможные ошибки -> {'амз', 'мзо'}
# Cлово -> чуть-чуть | Возможные ошибки -> {'ь-ч', '-чу'}
# Cлово -> auxquelles | Возможные ошибки -> {'uxq', 'xqu'}
# Cлово -> parfaitement | Возможные ошибки -> {'rfa', 'arf'}
# Cлово -> чудацкое | Возможные ошибки -> {'дац', 'ацк'}
# Cлово -> воля-с | Возможные ошибки -> {'ля-', 'я-с'}
# Cлово -> ха-ха-ха | Возможные ошибки -> {'-ха', 'а-х', 'ха-'}
# Cлово -> один-на-один | Возможные ошибки -> {'н-н', '-од', 'ин-', 'а-о'}
# Cлово -> diablement | Возможные ошибки -> {'iab', 'dia'}
# Cлово -> кофточке | Возможные ошибки -> {'фто', 'офт'}
# Cлово -> чепце | Возможные ошибки -> {'чеп', 'епц', 'пце'}
# Cлово -> ямами | Возможные ошибки -> {'яма', '#ям'}
# Cлово -> туфли | Возможные ошибки -> {'уфл', 'туф'}
# Cлово -> арифметической | Возможные ошибки -> {'фме', 'ифм', 'риф'}
# Cлово -> oublrai | Возможные ошибки -> {'lra', 'blr'}
# Cлово -> на-цыпочках | Возможные ошибки -> {'-цы', 'а-ц'}
# Cлово -> voua | Возможные ошибки -> {'ua#', 'oua'}
# Cлово -> нюни | Возможные ошибки -> {'юни', '#ню', 'нюн'}
# Cлово -> петю | Возможные ошибки -> {'тю#', 'етю'}
# Cлово -> m-r | Возможные ошибки -> {'m-r', '-r#'}
# Cлово -> миллионов-миллионов | Возможные ошибки -> {'в-м', '-ми'}
# Cлово -> образцом | Возможные ошибки -> {'азц', 'зцо'}
# Cлово -> обзаведения | Возможные ошибки -> {'бза', 'обз'}
# Cлово -> 12-го | Возможные ошибки -> {'2-г', '12-'}
# Cлово -> 15-ти | Возможные ошибки -> {'5-т', '15-'}
# Cлово -> 15-ти | Возможные ошибки -> {'5-т', '15-'}
# Cлово -> снабженные | Возможные ошибки -> {'абж', 'бже'}
# Cлово -> пирамидкой | Возможные ошибки -> {'идк', 'мид'}
# Cлово -> петизанфан | Возможные ошибки -> {'анф', 'нфа'}
# Cлово -> ущипнуть | Возможные ошибки -> {'щип', 'ипн'}
# Cлово -> армейщина | Возможные ошибки -> {'йщи', 'ейщ'}
# Cлово -> хозяевам | Возможные ошибки -> {'зяе', 'яев'}
# Cлово -> альфонс | Возможные ошибки -> {'льф', 'ьфо'}
# Cлово -> карлычем | Возможные ошибки -> {'лыч', 'рлы'}
# Cлово -> немчура | Возможные ошибки -> {'емч', 'мчу', 'чур'}
# Cлово -> свихнул | Возможные ошибки -> {'ихн', 'вих'}
# Cлово -> дуэли | Возможные ошибки -> {'уэл', 'эли', 'дуэ'}
# Cлово -> 80-титысячной | Возможные ошибки -> {'80-', '#80'}
# Cлово -> шарфах | Возможные ошибки -> {'фах', 'рфа'}
# Cлово -> расфранченные | Возможные ошибки -> {'сфр', 'асф'}
# Cлово -> аммуницией | Возможные ошибки -> {'амм', 'мму'}
# Cлово -> флюгера | Возможные ошибки -> {'люг', 'флю', 'юге'}
# Cлово -> !! | Возможные ошибки -> {'!!#', '#!!'}
# Cлово -> самоотвержения | Возможные ошибки -> {'оот', 'моо'}
# Cлово -> !? | Возможные ошибки -> {'#!?', '!?#'}
# Cлово -> замке | Возможные ошибки -> {'мке', 'амк'}
# Cлово -> аллюра | Возможные ошибки -> {'люр', 'ллю'}
# Cлово -> шварцернберга | Возможные ошибки -> {'нбе', 'рнб'}
# Cлово -> сегодняшнего | Возможные ошибки -> {'яшн', 'няш'}
# Cлово -> chef | Возможные ошибки -> {'hef', 'ef#'}
# Cлово -> пристально-холодным | Возможные ошибки -> {'-хо', 'о-х'}
# Cлово -> 16 | Возможные ошибки -> {'16#', '#16'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> алё | Возможные ошибки -> {'лё#', 'алё'}
# Cлово -> huzards | Возможные ошибки -> {'zar', 'huz', 'uza'}
# Cлово -> pavlograd | Возможные ошибки -> {'log', 'rad', 'vlo', 'ad#', 'avl'}
# Cлово -> huzards | Возможные ошибки -> {'zar', 'huz', 'uza'}
# Cлово -> pavlograd | Возможные ошибки -> {'log', 'rad', 'vlo', 'ad#', 'avl'}
# Cлово -> приученная | Возможные ошибки -> {'риу', 'иуч'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> государя-императора | Возможные ошибки -> {'я-и', 'ря-'}
# Cлово -> 17-го | Возможные ошибки -> {'7-г', '#17', '17-'}
# Cлово -> 19-го | Возможные ошибки -> {'9-г', '19-'}
# Cлово -> 80-титысячная | Возможные ошибки -> {'80-', '#80'}
# Cлово -> циферблате | Возможные ошибки -> {'циф', '#ци'}
# Cлово -> обер-гофмаршалу | Возможные ошибки -> {'фма', 'офм'}
# Cлово -> rr | Возможные ошибки -> {'#rr', 'rr#'}
# Cлово -> wimpfen | Возможные ошибки -> {'mpf', 'pfe'}
# Cлово -> hohenloe | Возможные ошибки -> {'hoh', 'loe', 'nlo', 'oe#', 'ohe'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> prsch | Возможные ошибки -> {'prs', 'rsc'}
# Cлово -> noms | Возможные ошибки -> {'ms#', 'oms'}
# Cлово -> вимпфен | Возможные ошибки -> {'пфе', 'фен', 'мпф'}
# Cлово -> гогенлое | Возможные ошибки -> {'енл', 'нло'}
# Cлово -> пришпршипрш | Возможные ошибки -> {'ишп', 'ипр', 'шпр', 'шип', 'прш'}
# Cлово -> злоязычие | Возможные ошибки -> {'лоя', 'ояз'}
# Cлово -> аракчеев | Возможные ошибки -> {'акч', 'кче', 'чее'}
# Cлово -> riz | Возможные ошибки -> {'iz#', 'riz'}
# Cлово -> 8-м | Возможные ошибки -> {'8-м', '#8-'}
# Cлово -> wald | Возможные ошибки -> {'wal', '#wa'}
# Cлово -> bedeckten | Возможные ошибки -> {'ckt', 'kte'}
# Cлово -> lehnt | Возможные ошибки -> {'hnt', 'ehn', 'leh'}
# Cлово -> laengs | Возможные ошибки -> {'ngs', 'gs#', 'lae', 'aen'}
# Cлово -> sokolienitz | Возможные ошибки -> {'sok', 'oko'}
# Cлово -> befindiichen | Возможные ошибки -> {'dii', 'iic'}
# Cлово -> zieht | Возможные ошибки -> {'#zi', 'ieh', 'eht', 'zie'}
# Cлово -> sehr | Возможные ошибки -> {'seh', 'ehr', 'hr#'}
# Cлово -> vortheilhaft | Возможные ошибки -> {'lha', 'ilh', 'haf'}
# Cлово -> letzteren | Возможные ошибки -> {'tzt', 'zte', 'etz'}
# Cлово -> attakiren | Возможные ошибки -> {'kir', 'aki', 'tak'}
# Cлово -> doerfer | Возможные ошибки -> {'doe', 'oer'}
# Cлово -> sokolienitz | Возможные ошибки -> {'sok', 'oko'}
# Cлово -> wodurch | Возможные ошибки -> {'wod', 'odu'}
# Cлово -> zugleich | Возможные ошибки -> {'ugl', 'zug'}
# Cлово -> ihn | Возможные ошибки -> {'#ih', 'hn#', 'ihn'}
# Cлово -> flaeche | Возможные ошибки -> {'fla', 'aec', 'lae'}
# Cлово -> zwischen | Возможные ошибки -> {'zwi', '#zw', 'isc', 'wis'}
# Cлово -> thuerassa-walde | Возможные ошибки -> {'a-w', '-wa', 'wal', 'hue', 'thu', 'sa-'}
# Cлово -> verfolgen | Возможные ошибки -> {'olg', 'fol', 'rfo', 'lge'}
# Cлово -> koennen | Возможные ошибки -> {'koe', 'oen'}
# Cлово -> defileen | Возможные ошибки -> {'lee', 'een'}
# Cлово -> bellowitz | Возможные ошибки -> {'wit', 'owi', 'low'}
# Cлово -> ausweichen | Возможные ошибки -> {'usw', 'swe'}
# Cлово -> welche | Возможные ошибки -> {'elc', 'lch'}
# Cлово -> feindliche | Возможные ошибки -> {'dli', 'ndl'}
# Cлово -> endzwecke | Возможные ошибки -> {'dzw', 'ndz', 'zwe', 'wec'}
# Cлово -> zweite | Возможные ошибки -> {'#zw', 'zwe'}
# Cлово -> дефилеи | Возможные ошибки -> {'ефи', 'деф'}
# Cлово -> буксгевден | Возможные ошибки -> {'укс', 'ксг', 'гев', 'сге'}
# Cлово -> южного | Возможные ошибки -> {'#юж', 'южн'}
# Cлово -> geographie | Возможные ошибки -> {'geo', 'eog'}
# Cлово -> школьникам-ученикам | Возможные ошибки -> {'-уч', 'м-у'}
# Cлово -> государи-императоры | Возможные ошибки -> {'и-и', 'ри-'}
# Cлово -> ?.. | Возможные ошибки -> {'#?.', '?..'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> фланкёрской | Возможные ошибки -> {'кёр', 'ёрс', 'нкё'}
# Cлово -> лозунг | Возможные ошибки -> {'зун', 'унг'}
# Cлово -> рррр | Возможные ошибки -> {'рр#', 'ррр', '#рр'}
# Cлово -> ё | Возможные ошибки -> {'##ё', '#ё#'}
# Cлово -> фланкёры | Возможные ошибки -> {'кёр', 'ёры', 'нкё'}
# Cлово -> слушаю-с | Возможные ошибки -> {'аю-', 'ю-с'}
# Cлово -> бивуаки | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> 5 | Возможные ошибки -> {'#5#', '##5'}
# Cлово -> мачты | Возможные ошибки -> {'мач', 'чты', 'ачт'}
# Cлово -> то-есть | Возможные ошибки -> {'-ес', 'о-е'}
# Cлово -> гольдбахом | Возможные ошибки -> {'ьдб', 'дба'}
# Cлово -> холмы | Возможные ошибки -> {'лмы', 'олм'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> холмы | Возможные ошибки -> {'лмы', 'олм'}
# Cлово -> дефилею | Возможные ошибки -> {'ефи', 'деф'}
# Cлово -> слушаю-с | Возможные ошибки -> {'аю-', 'ю-с'}
# Cлово -> dites-lui | Возможные ошибки -> {'s-l', '-lu'}
# Cлово -> demandez-lui | Возможные ошибки -> {'-lu', 'z-l'}
# Cлово -> разноцветных | Возможные ошибки -> {'ноц', 'оцв'}
# Cлово -> молодцы-ординарцы | Возможные ошибки -> {'-ор', 'цы-', 'ы-о'}
# Cлово -> новгородского | Возможные ошибки -> {'овг', 'вго'}
# Cлово -> марш-марш | Возможные ошибки -> {'ш-м', 'рш-'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'-ап', 'в-а'}
# Cлово -> молодцов-апшеронцев | Возможные ошибки -> {'-ап', 'в-а'}
# Cлово -> ползущими | Возможные ошибки -> {'лзу', 'зущ'}
# Cлово -> 9-ть | Возможные ошибки -> {'9-т', '-ть'}
# Cлово -> аллюром | Возможные ошибки -> {'люр', 'ллю'}
# Cлово -> красавцев-людей | Возможные ошибки -> {'-лю', 'ев-', 'в-л'}
# Cлово -> рыцари | Возможные ошибки -> {'рыц', 'ыца'}
# Cлово -> по-чешски | Возможные ошибки -> {'шск', 'ешс'}
# Cлово -> обер-гофмаршал | Возможные ошибки -> {'фма', 'офм'}
# Cлово -> 4-й | Возможные ошибки -> {'#4-', '4-й'}
# Cлово -> тьфу | Возможные ошибки -> {'тьф', 'ьфу'}
# Cлово -> плюнув | Возможные ошибки -> {'люн', 'юну'}
# Cлово -> старичок-мельник | Возможные ошибки -> {'к-м', 'ок-'}
# Cлово -> трепещущую | Возможные ошибки -> {'пещ', 'щущ', 'ещу'}
# Cлово -> рыбу | Возможные ошибки -> {'ыбу', 'рыб'}
# Cлово -> навзничь | Возможные ошибки -> {'взн', 'авз'}
# Cлово -> 19-летний | Возможные ошибки -> {'-ле', '9-л', '19-'}
# Cлово -> бивуак | Возможные ошибки -> {'уак', 'вуа'}
# Cлово -> хаос | Возможные ошибки -> {'аос', 'хао'}
# Cлово -> sujet | Возможные ошибки -> {'suj', 'uje'}

# %% [markdown]
# ### 2.2. Бор
# Далее построим бор, с помощью которого будем искать исправления опечатки в слове. Пока только в случае замены и удаления в конце (Если есть желание, то можно и для всех случаев). Также сравнить по времени с поиском в случае замены в исходном слове последних двух символов и поиске в словаре.

# %%
class TrieNode():
    def __init__(self, char):
        self.char = char
        self.children = {}
        self.end = False
        
class Trie():
    def __init__(self):
        self.root = TrieNode("")
        
    def insert(self, word):
        node = self.root
        
        for char in word:
            if char in node.children:
                node = node.children[char]
            else:
                trie_node = TrieNode(char)
                node.children[char] = trie_node
                node = trie_node
                
        node.end = True
    
    def search(self, node, prefix):
        if node.end:
            self.output.append((prefix + node.char))
            
        for child in node.children.values():
            self.search(child, prefix + node.char)
            
    def get_words(self, prefix):
        self.output = []
        node = self.root
        
        for char in prefix:
            if char in node.children:
                node = node.children[char]
            else:
                return []
            
        self.search(node, prefix[:-1])

        return self.output
    
    def get_simillar_words(self, prefix, errors):
        pass

# %%
trie = Trie()

for word in wordlist:
    trie.insert(word.text)

# %%
def call_counter(func):
    def helper(*args, **kwargs):
        helper.calls += 1
        return func(*args, **kwargs)
    helper.calls = 0
    helper.__name__= func.__name__

    return helper


memo = {}
@call_counter
def levenshtein(s, t):
    if s == "":
        return len(t)
    if t == "":
        return len(s)
    cost = 0 if s[-1] == t[-1] else 1
       
    i1 = (s[:-1], t)
    if not i1 in memo:
        memo[i1] = levenshtein(*i1)
    i2 = (s, t[:-1])
    if not i2 in memo:
        memo[i2] = levenshtein(*i2)
    i3 = (s[:-1], t[:-1])
    if not i3 in memo:
        memo[i3] = levenshtein(*i3)
    res = min([memo[i1]+1, memo[i2]+1, memo[i3]+cost])
    
    return res

print(levenshtein("каровя", "корова"))
# Out:
# 2

# %%
def correct_word(word):
    return trie.get_words(word)
    

def char_range(c1, c2):
    """Generates the characters from `c1` to `c2`, inclusive."""
    for c in range(ord(c1), ord(c2)+1):
        yield chr(c)

def correct_word_naive(word, dictionary):
    """
        Corrects word using naive approach (search most similar word in the dicitionary)
    """
    distances = [(candidate.text, levenshtein(word.lower(), candidate.text)) for candidate in dictionary]
    min_distance = sorted(distances, key=lambda x: x[1])[0][1]

    candidates = [word[0] for word in distances if word[1] == min_distance]

    return '<{}>: [{}]'.format(word, '|'.join(candidates))

# %%
correct_word_naive('коровя', wordlist)
# Out:
# '<коровя>: [короля|короля|корова]'

# %%
sample = '''лев николаевич талстой война и мип том чусть пегвая е паместья мой верный рап ну что князь генуа и лука стали не
бальше как паместьяни фамили бонапарте нет я вас предупреждааю если вы мне ни скажете что у нас вайна если вы еще позволете 
себе зашишать все гадасты все ужаси этого антихриста права я верю что он антехрест я вас больше не знаю вы уж не друх мой вы 
уш не мой верный раб как вы говориде ну здравствуйде здравствуйте я вижу что я вас пугаю садитесь и расказывайте так гаворила
в июле года известная анна павловна шерер фрейлина и'''

# %%
# %%time

correct_word_naive(wordlist, sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-12-a3a2f3a34b86> in correct_word_naive(word_dict, word)
#      17         for s in char_range('a', 'я'):
#      18             candidate = pref + f + s
# ---> 19             if candidate in word_dict:
#      20                 if f == word[-2] or s == word[-1]:
#      21                     return candidate
#
# c:\users\shkun\appdata\local\programs\python\python38\lib\site-packages\razdel\record.py in __eq__(self, other)
#      18     def __eq__(self, other):
#      19         return (
# ---> 20             type(self) == type(other)
#      21             and all(
#      22                 (getattr(self, _) == getattr(other, _))
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2.3 Все вместе
# Теперь соберем поиск и исправление опечаток в одну систему, которая будет принимать текст и править его. Также замерим скорость по сравнению с "менее наивным подходом".

# %%
def correct_mistakes(text):
    '''returns corrected text'''
    pass

def correct_mistakes_naive(text):
    '''returns corrected text using generation'''
    pass
